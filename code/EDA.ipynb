# %%
import pandas as pd
import os

# Path to the directory containing the raw CSV files
data_path = '../data:clean'

# List all files in the directory
files = os.listdir(data_path)

# Filter for CSV files
csv_files = [file for file in files if file.endswith('.csv')]

# Apply the describe function to each CSV file
for csv_file in csv_files:
    file_path = os.path.join(data_path, csv_file)
    df = pd.read_csv(file_path)
    print(f"Description for {csv_file}:")
    print(df.describe())
    print('\\n' + '-'*50 + '\\n')
# Out:
# Description for the_finals_2024-12-05_to_2025-01-02.csv:
#             Players
# count     29.000000
# mean   17108.689655
# std     2228.733995
# min    14097.000000
# 25%    15480.000000
# 50%    16733.000000
# 75%    17786.000000
# max    23470.000000
# \n--------------------------------------------------\n
# Description for deep_rock_galactic_2024-05-30_to_2024-07-04.csv:
#             Players
# count     36.000000
# mean   27956.361111
# std    13540.077350
# min    10380.000000
# 25%    13148.500000
# 50%    29888.000000
# 75%    38966.000000
# max    54160.000000
# \n--------------------------------------------------\n
# Description for rainbow_six_siege_2024-08-19_to_2024-09-16.csv:
#             Players
# count     29.000000
# mean   65268.413793
# std     9514.712178
# min    54120.000000
# 25%    56374.000000
# 50%    64010.000000
# 75%    70421.000000
# max    91165.000000
# \n--------------------------------------------------\n
# Description for palworld_2024-12-09_to_2025-01-13.csv:
#              Players
# count      36.000000
# mean   126708.861111
# std     69530.435778
# min     33821.000000
# 25%     46766.500000
# 50%    153937.000000
# 75%    189670.000000
# max    212817.000000
# \n--------------------------------------------------\n
# Description for warframe_2025-11-26_to_2025-12-31.csv:
#              Players
# count      36.000000
# mean   106446.666667
# std     26356.518609
# min     72137.000000
# 25%     80396.500000
# 50%    111337.500000
# 75%    123326.000000
# max    175546.000000
# \n--------------------------------------------------\n
# Description for no_man_s_sky_2025-01-15_to_2025-02-19.csv:
#             Players
# count     36.000000
# mean   22691.055556
# std    11777.946607
# min     8195.000000
# 25%     9707.500000
# 50%    25921.000000
# 75%    31883.000000
# max    43695.000000
# \n--------------------------------------------------\n
# Description for dead_by_daylight_2023-11-14_to_2023-12-19.csv:
#             Players
# count     36.000000
# mean   41177.916667
# std     5391.531436
# min    34866.000000
# 25%    36724.500000
# 50%    39196.500000
# 75%    44450.000000
# max    58019.000000
# \n--------------------------------------------------\n
# Description for path_of_exile_2025-06-06_to_2025-07-04.csv:
#              Players
# count      29.000000
# mean    88117.931034
# std     49307.976337
# min      7569.000000
# 25%     82813.000000
# 50%    100439.000000
# 75%    118588.000000
# max    179556.000000
# \n--------------------------------------------------\n
# Description for don_t_starve_together_2023-04-13_to_2023-05-18.csv:
#              Players
# count      36.000000
# mean    65046.694444
# std     29714.475726
# min     29375.000000
# 25%     35614.500000
# 50%     63180.500000
# 75%     90404.500000
# max    115925.000000
# \n--------------------------------------------------\n
# Description for pubg__battlegrounds_2025-10-22_to_2025-11-26.csv:
#              Players
# count      36.000000
# mean   645912.805556
# std     33612.032454
# min    591321.000000
# 25%    619537.750000
# 50%    642988.500000
# 75%    664394.750000
# max    755104.000000
# \n--------------------------------------------------\n
# Description for v_rising_2025-04-21_to_2025-05-19.csv:
#             Players
# count     29.000000
# mean   44094.000000
# std    23087.871688
# min     5925.000000
# 25%    37420.000000
# 50%    51436.000000
# 75%    59001.000000
# max    76730.000000
# \n--------------------------------------------------\n
# Description for counter_strike_2_2024-04-23_to_2024-05-28.csv:
#             Players
# count  3.600000e+01
# mean   1.494634e+06
# std    7.969190e+04
# min    1.263426e+06
# 25%    1.470874e+06
# 50%    1.502156e+06
# 75%    1.552522e+06
# max    1.631616e+06
# \n--------------------------------------------------\n
# Description for destiny_2_2024-09-24_to_2024-10-29.csv:
#             Players
# count     36.000000
# mean   45207.722222
# std    16533.211166
# min    24629.000000
# 25%    31517.000000
# 50%    41549.000000
# 75%    54006.750000
# max    89537.000000
# \n--------------------------------------------------\n
# Description for sea_of_thieves_2024-10-03_to_2024-11-07.csv:
#             Players
# count     36.000000
# mean   11309.916667
# std     2165.630893
# min     7791.000000
# 25%     9422.000000
# 50%    11370.500000
# 75%    13093.750000
# max    15873.000000
# \n--------------------------------------------------\n
# Description for apex_legends_2025-01-28_to_2025-03-04.csv:
#              Players
# count      36.000000
# mean   162393.638889
# std     37340.148948
# min     94512.000000
# 25%    140839.500000
# 50%    160168.000000
# 75%    195371.250000
# max    226225.000000
# \n--------------------------------------------------\n
# Description for helldivers_2_2025-08-19_to_2025-09-23.csv:
#              Players
# count      36.000000
# mean   105813.861111
# std     40272.154196
# min     39817.000000
# 25%     76768.250000
# 50%    109236.500000
# 75%    137192.500000
# max    178795.000000
# \n--------------------------------------------------\n

# %%
from tabulate import tabulate
import os

# Create a dictionary to hold the descriptions
descriptions = {}

# Apply the describe function to each CSV file and store it
for csv_file in csv_files:
    file_path = os.path.join(data_path, csv_file)
    df = pd.read_csv(file_path)
    descriptions[csv_file] = df.describe()

# Now, let's format this for the markdown file
markdown_output = "## Clean Data Summary\n\n"
for game, desc_df in descriptions.items():
    markdown_output += f"### {game}\n\n"
    markdown_output += desc_df.to_markdown()
    markdown_output += "\n\n"

# Define the output path using a relative path from the Code directory
output_path = "../outputs/clean_data_summary.md"

# Write the output to a file
with open(output_path, "w") as f:
    f.write(markdown_output)

print(f"Clean data summary has been written to {os.path.abspath(output_path)}")
# Out:
# Clean data summary has been written to /Users/timothytran/Documents/Python/clone/project/ecc3479-project/outputs/clean_data_summary.md

# %%
import os
print(f"The current working directory is: {os.getcwd()}")
# Out:
# The current working directory is: /Users/timothytran/Documents/Python/clone/ecc3479-project/Code
